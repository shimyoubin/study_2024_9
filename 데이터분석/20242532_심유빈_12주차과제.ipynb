# %% [markdown]
# ## 1

# %%
import csv

f = open('subwaytime.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
next(data)

max_people = 0
max_station = ''
t = int(input('몇 시의 승차 인원이 가장 많은 역이 궁금하세요?: '))

for row in data:
    for i in range(4, 52):
        row[i] = row[i].replace(',', "")

    row[4:] = map(int, row[4:])
    people = row[2 * t - 4]
    if people > max_people:
        max_people = people
        max_station = row[3] + '(' + row[1] + ')'

f.close()

print(max_station, ':', max_people, '명')
# Out:
# 홍대입구(2호선) : 81164 명

# %%
import csv

f = open('subwaytime.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
next(data)

max_people = [0] * 24
max_station = [''] * 24

for row in data:
    for i in range(4, 52):
        row[i] = row[i].replace(',', "")

    row[4:] = map(int, row[4:])
    for j in range(24):
        people = row[2 * j + 4]
        if people > max_people[j] :
            max_people[j] = people
            max_station[j] = row[3]

f.close()

print(max_station)
print(max_people)
# Out:
# ['구로', '신림', '신림', '신림', '신림', '신림', '신림', '잠실(송파구청)', '잠실(송파구청)', '강남', '강남', '강남', '강남', '강남', '강남', '강남', '잠실(송파구청)', '강남', '강남', '홍대입구', '강남', '금정', '동암', '용산']
# [11898, 38345, 71039, 184073, 274665, 165979, 88153, 76852, 84468, 98834, 106471, 131677, 154492, 241721, 321759, 197282, 153516, 177679, 167850, 81164, 14129, 29, 2, 1]

# %%
import csv
import matplotlib.pyplot as plt

f = open('subwaytime.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
next(data)

max_people = [0] * 24
max_station = [''] * 24

for row in data:
    for i in range(4, 52):
        row[i] = row[i].replace(',', "")

    row[4:] = map(int, row[4:])
    for j in range(24):
        people = row[2 * j + 4]
        if people > max_people[j] :
            max_people[j] = people
            max_station[j] = row[3]

f.close()

plt.rc('font', family='AppleGothic')
plt.bar(range(24), max_people)
plt.xticks(range(24), max_station, rotation=90)
plt.grid(True)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('subwaytime.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
next(data)

max_people = [0] * 24
max_station = [''] * 24

for row in data:
    for i in range(4, 52):
        row[i] = row[i].replace(',', "")

    row[4:] = map(int, row[4:])
    for j in range(24):
        people = row[2 * j + 4]
        if people > max_people[j] :
            max_people[j] = people
            max_station[j] = row[3] + '(' + str(j+4) + ')'

f.close()

plt.rc('font', family='AppleGothic')
plt.bar(range(24), max_people)
plt.xticks(range(24), max_station, rotation=90)
plt.grid(True)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('subwaytime.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
next(data)

max_people = [0] * 24
max_station = [''] * 24

for row in data:
    for i in range(4, 52):
        row[i] = row[i].replace(',', "")

    row[4:] = map(int, row[4:])
    for j in range(24):
        people = row[2 * j + 4]
        if people > max_people[j] :
            max_people[j] = people
            max_station[j] = row[3] + f'({str((j + 4) % 24)})'
f.close()

plt.rc('font', family='AppleGothic')
plt.bar(range(24), max_people)
plt.xticks(range(24), max_station, rotation=90)
plt.grid(True)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('subwaytime.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
next(data)

max_people = [0] * 24
max_station = [''] * 24

for row in data:
    for i in range(4, 52):
        row[i] = row[i].replace(',', "")

    row[4:] = map(int, row[4:])
    for j in range(24):
        people = row[2 * j + 5]
        if people > max_people[j] :
            max_people[j] = people
            max_station[j] = row[3] + f'({str((j + 4) % 24)})'
f.close()

plt.rc('font', family='AppleGothic')
plt.bar(range(24), max_people, color='pink')
plt.xticks(range(24), max_station, rotation=90)
plt.grid(True)
plt.show()

# %%
import csv
f = open('subwaytime.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)
next(data)

s_in = [0] * 24
s_out = [0] * 24

for row in data:
    for i in range(4, 52):
        row[i] = row[i].replace(',',"")

    row[4:] = map(int, row[4:])
    for i in range(24):
        s_in[i] = s_in[i] + row[2 * i +4]
        s_out[i] = s_out[i] + row[2 * i +5]

f.close()

# %%
import csv
import matplotlib.pyplot as plt

f = open('subwaytime.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)
next(data)

s_in = [0] * 24
s_out = [0] * 24

for row in data:
    for i in range(4, 52):
        row[i] = row[i].replace(',',"")

    row[4:] = map(int, row[4:])
    for i in range(24):
        s_in[i] = s_in[i] + row[2 * i +4]
        s_out[i] = s_out[i] + row[2 * i +5]

f.close()

plt.rc('font', family='AppleGothic')
plt.title('자하철 시간대별 승하차 인원 추이')
plt.plot(s_in,label='승차')
plt.plot(s_out, label='하차')
plt.legend()
plt.grid(True)
plt.xticks(range(24), range(4, 28))
plt.show()

# %%
max_people = [0] * 4
print(max_people)
# Out:
# [0, 0, 0, 0]

# %%
max_station = [''] * 4
print(max_station)
# Out:
# ['', '', '', '']

# %%
import csv
import matplotlib.pyplot as plt

f = open('subwayfee.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
next(data)

max_people = [0] * 4
max_station = [''] * 4

label = ['유임승차', '유임하차', '무임승차', '무임하차']

for row in data :
    for i in range(4, 8) :
        row[i] = int(row[i].replace(',',""))
        if row[i] > max_people[i - 4]:
            max_people[i - 4] = row[i]
            max_station[i -4 ] = row[3] + ' ' + row[1]

f.close()

for i in range(4):
    print(f'{label[i]}: {max_station[i]}, {max_people[i]} 명')
# Out:
# 유임승차: 잠실(송파구청) 2호선, 2106912 명
# 유임하차: 홍대입구 2호선, 2210524 명
# 무임승차: 종로3가 1호선, 318029 명
# 무임하차: 제기동 1호선, 303921 명

# %%
import csv
import matplotlib.pyplot as plt

f=open('subwayfee.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)
label = ['유임승차', '유임하차', '무임승차', '무임하차']
color = ['skyblue', 'palegreen' , 'pink', 'beige']

for row in data:
    for i in range(4, 8):
        row[i] = int(row[i].replace(',',""))

    plt.title(row[3] + ' ' + row[1])
    plt.pie(row[4:8], labels=label, colors=color, autopct='%1.f%%')
    #plt.savefig(row[3] + '' + row[1] + '.png')
    #plt.show()

f.close()

# %% [markdown]
# ## 2

# %%
import csv
f = open('age.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

print(header)

for row in data:
    print(row)
    break

f.close()
# Out:
# ['행정구역', '2023년09월_계_총인구수', '2023년09월_계_연령구간인구수', '2023년09월_계_0세', '2023년09월_계_1세', '2023년09월_계_2세', '2023년09월_계_3세', '2023년09월_계_4세', '2023년09월_계_5세', '2023년09월_계_6세', '2023년09월_계_7세', '2023년09월_계_8세', '2023년09월_계_9세', '2023년09월_계_10세', '2023년09월_계_11세', '2023년09월_계_12세', '2023년09월_계_13세', '2023년09월_계_14세', '2023년09월_계_15세', '2023년09월_계_16세', '2023년09월_계_17세', '2023년09월_계_18세', '2023년09월_계_19세', '2023년09월_계_20세', '2023년09월_계_21세', '2023년09월_계_22세', '2023년09월_계_23세', '2023년09월_계_24세', '2023년09월_계_25세', '2023년09월_계_26세', '2023년09월_계_27세', '2023년09월_계_28세', '2023년09월_계_29세', '2023년09월_계_30세', '2023년09월_계_31세', '2023년09월_계_32세', '2023년09월_계_33세', '2023년09월_계_34세', '2023년09월_계_35세', '2023년09월_계_36세', '2023년09월_계_37세', '2023년09월_계_38세', '2023년09월_계_39세', '2023년09월_계_40세', '2023년09월_계_41세', '2023년09월_계_42세', '2023년09월_계_43세', '2023년09월_계_44세', '2023년09월_계_45세', '2023년09월_계_46세', '2023년09월_계_47세', '2023년09월_계_48세', '2023년09월_계_49세', '2023년09월_계_50세', '2023년09월_계_51세', '2023년09월_계_52세', '2023년09월_계_53세', '2023년09월_계_54세', '2023년09월_계_55세', '2023년09월_계_56세', '2023년09월_계_57세', '2023년09월_계_58세', '2023년09월_계_59세', '2023년09월_계_60세', '2023년09월_계_61세', '2023년09월_계_62세', '2023년09월_계_63세', '2023년09월_계_64세', '2023년09월_계_65세', '2023년09월_계_66세', '2023년09월_계_67세', '2023년09월_계_68세', '2023년09월_계_69세', '2023년09월_계_70세', '2023년09월_계_71세', '2023년09월_계_72세', '2023년09월_계_73세', '2023년09월_계_74세', '2023년09월_계_75세', '2023년09월_계_76세', '2023년09월_계_77세', '2023년09월_계_78세', '2023년09월_계_79세', '2023년09월_계_80세', '2023년09월_계_81세', '2023년09월_계_82세', '2023년09월_계_83세', '2023년09월_계_84세', '2023년09월_계_85세', '2023년09월_계_86세', '2023년09월_계_87세', '2023년09월_계_88세', '2023년09월_계_89세', '2023년09월_계_90세', '2023년09월_계_91세', '2023년09월_계_92세', '2023년09월_계_93세', '2023년09월_계_94세', '2023년09월_계_95세', '2023년09월_계_96세', '2023년09월_계_97세', '2023년09월_계_98세', '2023년09월_계_99세', '2023년09월_계_100세 이상']
# ['서울특별시  (1100000000)', '9,407,540', '9,407,540', '38,101', '41,599', '43,518', '44,893', '48,097', '51,107', '56,215', '64,176', '66,545', '66,588', '68,791', '73,452', '73,667', '70,811', '70,182', '75,957', '76,605', '71,528', '72,968', '85,145', '88,965', '95,128', '114,431', '130,725', '134,291', '147,512', '157,700', '164,260', '165,915', '169,505', '169,721', '167,914', '154,238', '145,524', '139,088', '132,125', '129,417', '129,449', '128,551', '132,545', '141,799', '149,998', '151,352', '151,696', '141,877', '131,295', '134,730', '132,627', '140,149', '152,989', '154,654', '157,451', '166,643', '157,897', '159,261', '151,094', '139,108', '134,184', '138,870', '130,717', '141,481', '135,134', '151,553', '151,136', '137,487', '129,042', '128,405', '117,703', '123,829', '101,401', '92,397', '96,553', '70,066', '78,008', '78,177', '76,171', '75,999', '56,031', '55,814', '53,247', '54,490', '56,569', '44,137', '37,671', '34,905', '29,591', '25,447', '21,166', '18,331', '14,079', '11,132', '8,984', '6,319', '5,441', '4,430', '3,158', '2,286', '1,306', '916', '703', '1,505']

# %%
import csv
import numpy as np 
import matplotlib. pyplot as plt

f= open('age.csv', encoding='cp949')
data = csv. reader (f)
next (data)

name= input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
for row in data :
    row[2:] = map(lambda s: s.replace('', ''), row[2:])
    if name in row[0]:
        home = np.array(row[3:], dtype = int)
        break
f. close()

plt.rc('font', family='AppleGothic')
plt. plot (home)
plt.title(f'{name} 지역의 인구 구조')
plt. grid(True)
plt.xlabel ('나이')
plt.ylabel('인구수')
plt. show()

# %%
import csv
import numpy as np 
import matplotlib. pyplot as plt

f= open('age.csv', encoding='cp949')
data = csv. reader (f)
next (data)

name= input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
for row in data :
    row[2:] = map(lambda s: s.replace('', ''), row[2:])
    if name in row[0]:
        home = np.array(row[3:], dtype = int)
    if '화촌면' in row[0]:
        homeB = np.array(row[3:], dtype = int)
        print(row[0])
        
f. close()

plt.rc('font', family='AppleGothic')
plt. plot (home, label=name)
plt. plot (homeB, label='화촌면')
plt.title(f'{name} 지역의 인구 구조')
plt. grid(True)
plt.xlabel ('나이')
plt.ylabel('인구수')
plt. show()
# Out:
# 강원특별자치도 홍천군 화촌면(5172031000)

# %%
import csv
import numpy as np 
import matplotlib. pyplot as plt

f= open('age.csv', encoding='cp949')
data = csv. reader (f)
next (data)

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
for row in data :
    row[2:] = map(int, lambda s: s.replace(',', ""), row[2:])
    if name in row[0]:
        home = np.array(row[3:], dtype = int) / row[2]
    if '화촌면' in row[0]:
        homeB = np.array(row[3:], dtype = int) / row[2]
        print(row[0])
        
f. close()

plt.rc('font', family='AppleGothic')
plt. plot (home, label=name)
plt. plot (homeB, label='화촌면')
plt.title(f'{name} 지역의 인구 구조')
plt. grid(True)
plt.xlabel ('나이')
plt.ylabel('인구수')
plt. show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 11
#       9 name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
#      10 for row in data :
# ---> 11     row[2:] = map(int, lambda s: s.replace(',', ""), row[2:])
#      12     if name in row[0]:
#      13         home = np.array(row[3:], dtype = int) / row[2]
#
# TypeError: 'function' object is not iterable

# %%
import csv
import numpy as np 
import matplotlib. pyplot as plt

f= open('age.csv', encoding='cp949')
data = csv. reader (f)
header = next(data)
data = list(data)

min_val = 1
result_name =''
result =0

name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요: ')
for row in data:
    row[2:] = map(int, map(lambda s: s.replace(',', ""), row[2:]))
    if name in row[0]:
        home = np.array(row[3:], dtype=int) / row[2]

for row in data:
    if name not in row[0]:
        if row[2] == 0:
            continue

        away = np.array(row[3:], dtype=int) / row[2]
        s = np.sum((home-away ) ** 2)
        if s < min_val:
            min_val=s
            result_name = row[0]
            result = away

f.close()

plt.plot(home, label=name)
plt.plot(result, label=result_name)
plt.grid(True)
plt.show()

# %% [markdown]
# ## 3

# %%
import pandas as pd

index = pd.date_range('1/1/2024', periods=8)
index
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
import pandas as pd
import numpy as np

index = pd.date_range('1/1/2024', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns= list('ABC'))
df
# Out:
#                    A         B         C
# 2024-01-01  0.727741  0.159405  0.772389
# 2024-01-02  0.500446  0.747375  0.020691
# 2024-01-03  0.268117  0.055709  0.988135
# 2024-01-04  0.147779  0.516701  0.341781
# 2024-01-05  0.708537  0.665444  0.991406
# 2024-01-06  0.954267  0.266704  0.639388
# 2024-01-07  0.357136  0.663596  0.491258
# 2024-01-08  0.687826  0.795365  0.404476

# %%
import pandas as pd
import numpy as np

index = pd.date_range('1/1/2024', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns= list('ABC'))
df['B']
# Out:
# 2024-01-01    0.167389
# 2024-01-02    0.623349
# 2024-01-03    0.032283
# 2024-01-04    0.208907
# 2024-01-05    0.626247
# 2024-01-06    0.251836
# 2024-01-07    0.214880
# 2024-01-08    0.261236
# Freq: D, Name: B, dtype: float64

# %%
df['B'][0]
# Out:
# /var/folders/yx/q38n8qj93kjbwzg7m86gpzm80000gn/T/ipykernel_1820/2498547084.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['B'][0]
# 0.16738881596693134

# %%
import pandas as pd
import numpy as np

index = pd.date_range('1/1/2024', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns= list('ABC'))
print(df['B'] > 0.4)
# Out:
# 2024-01-01     True
# 2024-01-02    False
# 2024-01-03    False
# 2024-01-04    False
# 2024-01-05    False
# 2024-01-06    False
# 2024-01-07     True
# 2024-01-08     True
# Freq: D, Name: B, dtype: bool

# %%
import pandas as pd
import numpy as np

index = pd.date_range('1/1/2024', periods=8)
df = pd.DataFrame(np.random.rand(8,3), index=index, columns= list('ABC'))
df
# Out:
#                    A         B         C
# 2024-01-01  0.043159  0.039957  0.205989
# 2024-01-02  0.970118  0.939709  0.223718
# 2024-01-03  0.109245  0.107188  0.686203
# 2024-01-04  0.639971  0.324321  0.957521
# 2024-01-05  0.352222  0.778258  0.787336
# 2024-01-06  0.854622  0.583721  0.183961
# 2024-01-07  0.870286  0.765903  0.957058
# 2024-01-08  0.755770  0.192410  0.857649

# %%
df2 = df[df['B']>0.4]
df2
# Out:
#                    A         B         C
# 2024-01-02  0.970118  0.939709  0.223718
# 2024-01-05  0.352222  0.778258  0.787336
# 2024-01-06  0.854622  0.583721  0.183961
# 2024-01-07  0.870286  0.765903  0.957058

# %%
df2.T
# Out:
#    2024-01-02  2024-01-05  2024-01-06  2024-01-07
# A    0.970118    0.352222    0.854622    0.870286
# B    0.939709    0.778258    0.583721    0.765903
# C    0.223718    0.787336    0.183961    0.957058

# %%
df['D'] = df['A'] / df['B']
df
# Out:
#                    A         B         C         D
# 2024-01-01  0.043159  0.039957  0.205989  1.080121
# 2024-01-02  0.970118  0.939709  0.223718  1.032360
# 2024-01-03  0.109245  0.107188  0.686203  1.019187
# 2024-01-04  0.639971  0.324321  0.957521  1.973267
# 2024-01-05  0.352222  0.778258  0.787336  0.452577
# 2024-01-06  0.854622  0.583721  0.183961  1.464093
# 2024-01-07  0.870286  0.765903  0.957058  1.136287
# 2024-01-08  0.755770  0.192410  0.857649  3.927924

# %%
df['E'] = np.sum(df, axis=1)
df
# Out:
#                    A         B         C         D         E
# 2024-01-01  0.043159  0.039957  0.205989  1.080121  1.369227
# 2024-01-02  0.970118  0.939709  0.223718  1.032360  3.165905
# 2024-01-03  0.109245  0.107188  0.686203  1.019187  1.921823
# 2024-01-04  0.639971  0.324321  0.957521  1.973267  3.895079
# 2024-01-05  0.352222  0.778258  0.787336  0.452577  2.370392
# 2024-01-06  0.854622  0.583721  0.183961  1.464093  3.086396
# 2024-01-07  0.870286  0.765903  0.957058  1.136287  3.729534
# 2024-01-08  0.755770  0.192410  0.857649  3.927924  5.733753

# %%
df['F'] = np.ones(8)
df.head(3)
# Out:
#                    A         B         C         D         E    F
# 2024-01-01  0.043159  0.039957  0.205989  1.080121  1.369227  1.0
# 2024-01-02  0.970118  0.939709  0.223718  1.032360  3.165905  1.0
# 2024-01-03  0.109245  0.107188  0.686203  1.019187  1.921823  1.0

# %%
df1 = df.drop(['E', 'F'], axis='columns')
df1.head()
# Out:
#                    A         B         C         D
# 2024-01-01  0.043159  0.039957  0.205989  1.080121
# 2024-01-02  0.970118  0.939709  0.223718  1.032360
# 2024-01-03  0.109245  0.107188  0.686203  1.019187
# 2024-01-04  0.639971  0.324321  0.957521  1.973267
# 2024-01-05  0.352222  0.778258  0.787336  0.452577

# %%
del df1['D']
df1.head()
# Out:
#                    A         B         C
# 2024-01-01  0.043159  0.039957  0.205989
# 2024-01-02  0.970118  0.939709  0.223718
# 2024-01-03  0.109245  0.107188  0.686203
# 2024-01-04  0.639971  0.324321  0.957521
# 2024-01-05  0.352222  0.778258  0.787336

# %%
df1.columns=['a', 'b', 'c']

# %%
df1
# Out:
#                    a         b         c
# 2024-01-01  0.043159  0.039957  0.205989
# 2024-01-02  0.970118  0.939709  0.223718
# 2024-01-03  0.109245  0.107188  0.686203
# 2024-01-04  0.639971  0.324321  0.957521
# 2024-01-05  0.352222  0.778258  0.787336
# 2024-01-06  0.854622  0.583721  0.183961
# 2024-01-07  0.870286  0.765903  0.957058
# 2024-01-08  0.755770  0.192410  0.857649

# %%
df1.rename(columns = {'a': '2024', 'b': '2023'}, inplace=True)
df1.tail()
# Out:
#                 2024      2023         c
# 2024-01-04  0.639971  0.324321  0.957521
# 2024-01-05  0.352222  0.778258  0.787336
# 2024-01-06  0.854622  0.583721  0.183961
# 2024-01-07  0.870286  0.765903  0.957058
# 2024-01-08  0.755770  0.192410  0.857649

# %%
df1 = df1.sub(df1['2024'], axis='index')
df1.tail()
# Out:
#             2024      2023         c
# 2024-01-04   0.0 -0.315650  0.317550
# 2024-01-05   0.0  0.426036  0.435114
# 2024-01-06   0.0 -0.270901 -0.670661
# 2024-01-07   0.0 -0.104383  0.086772
# 2024-01-08   0.0 -0.563361  0.101879

# %%
df1 = df1.div(df1['c'], axis='index')
df1.tail()
# Out:
#             2024      2023    c
# 2024-01-04   0.0 -0.994018  1.0
# 2024-01-05   0.0  0.979137  1.0
# 2024-01-06  -0.0  0.403931  1.0
# 2024-01-07   0.0 -1.202951  1.0
# 2024-01-08   0.0 -5.529716  1.0

# %%
df1.to_csv('test.csv')
df1
